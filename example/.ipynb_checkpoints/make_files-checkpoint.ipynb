# %%
# %load_ext autoreload
# %autoreload 2
#import os
import DriftMLP
import networkx as nx
import os
file = os.environ['DRIFTFILE']
drift_kwargs = {'variables':['position','drogue', 'datetime'], 'drop_na':False, 'drogue':True}
day_cut_off=5
silent = False
network = DriftMLP.file_to_network(file, drift_kwargs, day_cut_off)
#drift_gen = DriftMLP.driftiter.generator(file)
#h3_stories=DriftMLP.story.get_story(drift_gen(**drift_kwargs))
#nx.write_gml(network, 'transition.gml')
## OR
#mlp_class = DriftMLP.MLP(file)
#nx.write_gml(mlp_class.net, 'transition.gml')

##
#mlp_class = DriftMLP.MLP('transition.gml')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#                        0     1
# 589972169660825599  53.0  42.0
# 589972307099779071  31.0  31.0
# 589972375819255807  43.0  43.0
# 589972513258209279  30.0  30.0
# 589972581977686015  28.0  19.0

# %%
from DriftMLP import shortest_path
sp_r = shortest_path.single_SP(network, [-23,17], [-48,44])
sp_r.plot_folium()
network.vs[0]
# Out:
# igraph.Vertex(<igraph.Graph object at 0x7f20067406d0>, 0, {'name': 590995677547331583, 'inN': 1400.0, 'outN': 1360.0})

# %%
print(sp_r.h3_inds)
print(sp_r.sp.h3id[0:2])
print(sp_r.sp.h3id[-1])
sp_r.plot_folium()
# Out:
# [591461870477508607, 590445646855536639]
# [591461870477508607, 591509493074886655]
# 590445646855536639
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import igraph
tpls = [(5e18,6e27,5), (7e32,9e22,33)]
int(igraph.Graph.TupleList(tpls, directed=True).vs['name'][0])
# Out:
# 5000000000000000000

# %%
help(h3.h3_set_to_multi_polygon)
# Out:
# Help on function h3_set_to_multi_polygon in module h3.api._api_template:
#
# h3_set_to_multi_polygon(hexes, geo_json=False)
#     Get GeoJSON-like MultiPolygon describing the outline of the area
#     covered by a set of H3 cells.
#
#     Parameters
#     ----------
#     hexes : unordered collection of H3Cell
#     geo_json : bool, optional
#         If `True`, output geo sequences will be lng/lat pairs, with the
#         last the same as the first.
#         If `False`, output geo sequences will be lat/lng pairs, with the
#         last distinct from the first.
#         Defaults to `False`
#
#     Returns
#     -------
#     list
#         List of "polygons".
#         Each polygon is a list of "geo sequences" like
#         `[outer, hole1, hole2, ...]`. The holes may not be present.
#         Each geo sequence is a list of lat/lng or lng/lat pairs.

# %%
sp_r.plot_folium()
# Out:
# ---------------------------------------------------------------------------
# H3CellError                               Traceback (most recent call last)
# <ipython-input-150-d35f89ffbe69> in <module>
# ----> 1 sp_r.plot_folium()
#
# ~/Documents/PhD_Docs/pydrifter_dev/DriftMLP/shortest_path/__init__.py in plot_folium(self, rev, m, **kwargs)
#     112     def plot_folium(self, rev=True, m=None, **kwargs):
#     113         if m is None:
# --> 114             m = plot_path(self.sp.h3id, color='blue', **kwargs)
#     115         if rev:
#     116             m = plot_path(self.sp_rev.h3id, color='red', folium_map=m)
#
# ~/Documents/PhD_Docs/pydrifter_dev/DriftMLP/shortest_path/__init__.py in plot_path(h3_seq, **kwargs)
#      18
#      19 def plot_path(h3_seq, **kwargs):
# ---> 20     m = h3_plotly.visualize_hexagons(h3_seq, **kwargs)
#      21     return m
#      22
#
# ...

# %%
sp_r
# Out:
# From: [-40, 17], To: [-48, 44]
# Travel time for the forward journey(blue)
# -1
# Travel time for the return joorney(red)
# -1

# %%
q = network.get_shortest_paths(90,90000, weights='neglogprob')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-103-d12dccca9dcc> in <module>
# ----> 1 q = network.get_shortest_paths(90,90000, weights='neglogprob')
#
# InternalError: Error at /home/conda/feedstock_root/build_artifacts/python-igraph_1588168236277/work/vendor/source/igraph/src/iterators.c:752: Cannot create iterator, invalid vertex id, Invalid vertex id

# %%
network.is_directed()
# Out:
# False

# %%
list(network.es.select(_source=src, _target=trg))
# Out:
# [igraph.Edge(<igraph.Graph object at 0x7f201f3bcd60>, 0, {'prob': 0.144, 'N': 36.0, 'neglogprob': 1.9379419794061366})]

# %%
import igraph 
from itertools import chain


unique_ids = list(set(chain.from_iterable(h3_stories)))
#Make a list where entry [i][j] contains transitions from i to j.
list_of_counters = DriftMLP.form_network.count_transitions(h3_stories, unique_ids,
                                     day_cut_off)
pd_adj = DriftMLP.form_network.nested_lists_of_count_to_pandas_edgelist(list_of_counters, unique_ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-92f8116e029a> in <module>
#       3
#       4
# ----> 5 unique_ids = list(set(chain.from_iterable(h3_stories)))
#       6 #Make a list where entry [i][j] contains transitions from i to j.
#       7 list_of_counters = DriftMLP.form_network.count_transitions(h3_stories, unique_ids,
#
# NameError: name 'h3_stories' is not defined

# %%
help(DriftMLP.form_network.add_story_to_lists)
# Out:
# Help on function add_story_to_lists in module DriftMLP.form_network:
#
# add_story_to_lists(story: List[int], list_of_counters: List[collections.Counter], day_cut_off: int = 5, observations_per_day: int = 4) -> None
#     Parameters
#     ----------
#     story : List[int]
#         A list containing a trajectory of states where each observations is `1/observations_per_day` apart in days.
#     list_of_counters : List[Counter]
#         The list of counters to update. Stores numbers of observations going for [i] to [j].
#     day_cut_off : int
#         A cut off that is the number in days. The transition matrix is estimated for state p_i -> p_{i+1} in day_cut_off days.
#     observations_per_day : int
#         The number of observations per day in story. e.g. 6 hourly observation implies 4 observations per day
#
#     Returns
#     -------

# %%
from_vs ,to_vs = h3_stories[1][5], h3_stories[3][9]
list(network.vs.select(name=from_vs))[0].index
# Out:
# [autoreload of DriftMLP.shortest_path failed: Traceback (most recent call last):
#   File "/home/omalley3/anaconda3/envs/driftmlp/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/omalley3/anaconda3/envs/driftmlp/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/omalley3/anaconda3/envs/driftmlp/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/omalley3/anaconda3/envs/driftmlp/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
# ...

# %%
help(network.vs.select)
# Out:
# Help on method select in module igraph:
#
# select(*args, **kwds) method of igraph.VertexSeq instance
#     Selects a subset of the vertex sequence based on some criteria
#
#     The selection criteria can be specified by the positional and the keyword
#     arguments. Positional arguments are always processed before keyword
#     arguments.
#
#       - If the first positional argument is C{None}, an empty sequence is
#         returned.
#
#       - If the first positional argument is a callable object, the object
#         will be called for every vertex in the sequence. If it returns
#         C{True}, the vertex will be included, otherwise it will
#         be excluded.
#
#       - If the first positional argument is an iterable, it must return
#         integers and they will be considered as indices of the current
#         vertex set (NOT the whole vertex set of the graph -- the
#         difference matters when one filters a vertex set that has
# ...

# %%
import h3.api.basic_int as h3
import numpy as np
h3.geo_to_h3(999, 3, 3)


#isinstance(np.nan, float)
# Out:
# 594187284924858367

# %%
[i  for story in h3_stories for i in story if i==0]
# Out:
# []

# %% [markdown]
# ## DO THIS NOW

# %%
from DriftMLP import rotations
from DriftMLP.rotations import random_ll_rot
rot_class = random_ll_rot()
rot_class(0,0)
# Out:
# (0.0, 0.0)

# %%
ireland = [-15, 54]
miami = [-80, 28]
all_edges = list(mlp_class.net.edges)
display(mlp_class.net.edges[all_edges[0]])
sp = mlp_class.get_mlpath(ireland,miami)
# Out:
# {'prob': 3.25874429719748e-05, 'N': 92060, 'neglogprob': 10.331583528703122}
# <class 'int'>
# ---------------------------------------------------------------------------
# NodeNotFound                              Traceback (most recent call last)
# <ipython-input-17-8e5043f46d96> in <module>
#       3 all_edges = list(mlp_class.net.edges)
#       4 display(mlp_class.net.edges[all_edges[0]])
# ----> 5 sp = mlp_class.get_mlpath(ireland,miami)
#
# ~/Documents/PhD_Docs/pydrifter_dev/DriftMLP/__init__.py in get_mlpath(self, lon, lat)
#      37
#      38     def get_mlpath(self, lon, lat):
# ---> 39         return shortest_path.single_SP(self.net, lon, lat)
#
# ~/Documents/PhD_Docs/pydrifter_dev/DriftMLP/shortest_path/__init__.py in __init__(self, network, orig, dest, weight)
#      45         self.h3_inds = return_h3_inds([orig, dest])
#      46         print(f'{type(self.h3_inds[0])}')
# ---> 47         self.sp = nx.shortest_path(network, self.h3_inds[0],
# ...

# %%
mlp_class.net[50]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-0abbbe6b9701> in <module>
# ----> 1 mlp_class.net[50]
#
# ~/anaconda3/envs/driftmlp/lib/python3.8/site-packages/networkx/classes/graph.py in __getitem__(self, n)
#     473         AtlasView({1: {}})
#     474         """
# --> 475         return self.adj[n]
#     476
#     477     def add_node(self, node_for_adding, **attr):
#
# ~/anaconda3/envs/driftmlp/lib/python3.8/site-packages/networkx/classes/coreviews.py in __getitem__(self, name)
#      79
#      80     def __getitem__(self, name):
# ---> 81         return AtlasView(self._atlas[name])
#      82
#      83     def copy(self):
#
# KeyError: 50

# %%
int(np.round(5.5))
# Out:
# 6

# %%
import h3.api.basic_int

# %%
all_edges = list(mlp_class.net.edges)

# %%
h3.geo_to_h3(0,1,resolution=3)

# %%
h3.geo_to_h3()
